# %% [markdown]
# # Overview of Descriptive & Exploratory statistics
# How to sneak a peek at your data:
# 1. Quantitative: How to calculate summary statistics
#     * Location
#        - Comparison of 'average': Mean, Mode, and Median
#     * Spread
#        - Variability, Variation, Standard Deviation, Range
#
# 2. Sampling biases & important concepts
#    - Accuracy/Bias versus Precision/Spread
#    - where to reinforce the plane?
#    - Standard Error
#
# 3. Qualitative: How to visualize your data appropriately
#    - Discussing how to quickly explore your data visually
#    - We have dedicated time for visualization on Day 8 across two modules

# %% [markdown]
# ## Extra Resources (if interested):
# 1. Crash course in statistics (youtube): https://www.youtube.com/watch?v=sxQaBpKfDRk
# 2. Free online textbook (with simulations): https://onlinestatbook.com/2/index.html
# 3. Flowchart (with coding in Python and R) for data visualization: https://www.data-to-viz.com

# %% [markdown]
# ## 1. Summary Statistics: Mean, mode Median
#
# You are considering buying a house in a certain neighbourhood. You find a potential house and, to appeal to perceived snobbiness as you are making your decision, your realtor mentions that the average income in this neighbourhood is $100,000 per year.
#
# You buy the house.
#
# A year later, the same realtor knocks on your door, this time acting as a representative of the neighbourhood taxpayers’ association. He would like you to sign a petition to decrease property taxes because, he says, the residents can’t afford an increase in property taxes since the average family income in the neighbourhood is only $25,000 per year.
#
# How is this possible, if the realtor is telling the truth, and no one in the neighbourhood has moved or changed jobs in the lastyear?

# %% [markdown]
# #### The two common summaries of data:
# 1. Location: Central Tendency
#     Where is the weight of the data?
#
#                     Average
#
# 2. Spread: How far apart are the data points?
#    Especially: how far apart are the largest and smallest data points?
#
# 			        Range
#
# You will also (much less commonly) see:
#
# 3. Skew – The third standardized moment; positive or negative skew. The shape of the distribution is not symmetric.
# 4. Kurtosis – The fourth standardized moment; sort of ‘peakness’ of the distribution (fatness of the tails)

# %% [markdown]
# ![Screenshot 2025-01-21 at 12.46.28 PM.png](attachment:206bc2df-95ef-43c3-b16d-041aa5185eac.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 12.46.46 PM.png](attachment:92b2051f-caec-4c08-8522-c36896d26cfc.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 12.47.14 PM.png](attachment:60df5a2f-7958-4869-a120-ab77253fa47c.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 12.48.27 PM.png](attachment:0958aaac-fc5f-407a-b06e-41d49dbc2e04.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 1.10.55 PM.png](attachment:8f281b31-e0f5-4746-9758-24819e870ecf.png)

# %% [markdown]
# #### Types of data:
# **
# Categorical Variabl**e*
# AKA Class variables or Nominal variable* s
# They do not have magnitude on a numerical sca* le
# Nom: nal
# Lack inherent o* rder
# O: dinal
# Inherent order
# Ex: blood type, genotype, sex, state, survival (live or die), drug treatment (aspirin vs ibup**rofen)
#
# Quantitative** * Variables
# AKA Numerical*  variables
# Random Variable is a Quantitati* ve variabl:
# Continuous
# Ability to take any value ex.. Hum; **n weight, age
# They **c* an be me: sured
# Discrete
# Spaces between possible values ex. Number ; **f offspring, age
# T**hey can be counted

# %% [markdown]
# ![Screenshot 2025-01-21 at 1.13.28 PM.png](attachment:a6a030c5-478b-4255-8a72-b070d506c048.png)

# %% [markdown]
# # 2. (Some) Important Concepts in Statistical Bias and Sampling

# %% [markdown]
# ![Screenshot 2025-01-21 at 1.17.31 PM.png](attachment:f9a30695-173f-48d0-99ba-3122d17b567d.png)

# %% [markdown]
# ### Where to reinforce the plane?
#
# ![image.png](attachment:e29be473-0474-46fb-9b19-c2af337b5f8a.png)

# %% [markdown]
# ### Will Rogers Phenomenon
#
# "When the Okies left Oklahoma and moved to California, they raised the average intelligence level in both states"
#
# (Actual medical phenomenon: "Medical Stage Migration")
#
# [Wikipedia Link](https://en.wikipedia.org/wiki/Will_Rogers_phenomenon)

# %% [markdown]
# ### Standard Error (through sampling)
#
# ![Screenshot 2025-01-21 at 1.21.34 PM.png](attachment:b06be057-a213-430d-84dc-7510832b621a.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 1.22.10 PM.png](attachment:578279b5-e180-4394-8e4f-27b7408dfb42.png)

# %% [markdown]
# # Group Questions:
# 1. Can the Standard deviation ever be zero? If so, when would that situation occur?
#
# 2. Imagine that we have a population that is skewed to the left. This population has a mean of 112 and a standard deviation of 16. Using a simulation program, Tyler simulated drawing 1000 samples of size 2 from the population. He then plotted the means for each of the samples that he drew. Alex simulated drawing 1000 samples of size 30, and he also plotted the means for each of the samples that he drew.
#
# a. Would you expect the shape of Tyler’ s distribution of sample means to differ from the shape of Alex’s distribution of sample means? Please explain your answer (i.e., If you do expect the shapes to differ, how will they differ? If you do not expect the shapes to differ, why not?)
# b.
# Is the mean of Tyler’s distribution of sample means <,>, or = to the mean of Alex’s distribution of sample means and to the mean of the sample?c.
# How would you rank, from largest to smallest, the following: the standard deviation of  Tyler’s distribution of sample means, the standard deviation of Alex’s distribution of sample means, and the standard deviation of the sample itself?
# lf?

# %% [markdown]
# # 3. Exploratory Data Visualization
# A good data visualization can help you:
# - identify anomalies in your data
# - better understand your own data
# - communicate your findings
#
# ### Data types and their common visualizations**
# - Scatterplots
# - Mosaic and bar plots
# -
# Histogrms
# -  Box and Violin plots-
# Cumulative Frequency Distributioncs

# %% [markdown]
# ### Extra Resources if you can't wait until day 8!*
# https://www.data-to-viz.com/   <--(and their code in Python and R)
#
# https://statisticsbyjim.com/graphs/
#
# https://piktochart.com/blog/types-of-graphs/
#
# https://www.sciencedirect.com/science/article/pii/S2666389920301896
#
# https://www.nature.com/articles/d41586-023-03393-9
#
# https://www.edwardtufte.com/tufte/
#
# https://monachalabi.com/
#
# * We will be discussing the material at these sites on Day 8 in the Visualization module

# %% [markdown]
# ## Data Type determines the plot type:
# ### Variable types : Plots
# - statistical/distribution of quantitative variable
#     - single variable
#         - histogram
#         - densityplot
#     - single variable x categorical variable
#         - boxplot
# - count data
#     - count data x categorical variable
#         - barplot
#     - count data x 2 categorical variables
#         - grouped bar plot
#         - stacked bar plot
# - Directly view quantitative variables
#     - one variable x time
#         - line plot
#     - one variable x time x categorical variable
#         - multiple lines on the same plot
#     - two (or maybe 3) quantitative variables
#         - scatter plot
#
# -------------
# #### The plots we will examine below:
# 1. Scatterplots
# 2. Histograms
# 3. Mosaic plots, Bar plots
# 4. Boxplots & Violin plots
# 5. Cumulative Frequency Plots

# %% [markdown]
# ### scatterplots: information about two quantitative variables and potential relationship
# ![Screenshot 2025-01-21 at 1.41.12 PM.png](attachment:9f95e237-e433-4f5a-bdf1-ae940a73dc95.png)

# %% [markdown]
# ### histograms: information about one quantitative variable
# ![Screenshot 2025-01-21 at 1.43.56 PM.png](attachment:5382ae52-0c69-418f-9edd-8aba001683aa.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 2.07.14 PM.png](attachment:ec2e66b2-e856-4e9e-af11-4d4d57f53cd0.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 2.08.01 PM.png](attachment:a75510c1-3799-4dd5-8206-864a692d17c0.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 2.08.54 PM.png](attachment:f2875b64-caef-4838-ab1d-ee2e62844d54.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 2.09.23 PM.png](attachment:d8075e54-d43c-414f-8446-a10a12433ace.png)

# %% [markdown]
# ![Screenshot 2025-01-21 at 2.10.21 PM.png](attachment:490c4788-aabd-4043-8074-9679054ada7c.png)

# %% [markdown]
# Identify a graph from a favourite publication and explain the following:
# 1. Identify the variables and their type.
# 2. What is the graph showing (or trying to show)?
# 3. Is the graph effective? Why or why not?
# 4. What improvements would you recommend for the graph and why?

# %% [markdown]
# #### Question #1
#
# You want to visualize how many people in your dataset prefer chocolate chip cookies and how many prefer oatmeal raisin cookies.
#
# **What type of visualization would be most appropriate?**
#
# - A) histogram
# - B) scatterplot
# - C) barplot
# - D) boxplot
# - E) line plot

# %% [markdown]
# #### Question #2
#
# You're interested in visualizing how many servings of milk an individual drinks each day among those who prefer chocolate chip cookies and those who prefer oatmeal raisin cookies.
#
# **What type of visualization would be most appropriate?**
#
# - A) histogram
# - B) scatterplot
# - C) barplot
# - D) boxplot
# - E) line plot

# %% [markdown]
# #### Question #3
#
# You're interested in visualizing how many servings of milk an individual drinks each year over the course of their life.
#
# **What type of visualization would be most appropriate?**
#
# - A) histogram
# - B) scatterplot
# - C) barplot
# - D) boxplot
# - E) line plot
